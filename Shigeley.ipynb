# %%
from BeamLib import *

# %%
BeamStructure = Beam(1)

Shigley = BeamLab(BeamStructure)
Shigley.AddLoadCase('Shigley_1')
Shigley.LoadCases['Shigley_1'].AddFixedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_1'].AddForce('b', Position = 1,Magnitude = -1)

Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# ElasticModulus: 210000000000.0
# C1   : 0.0
# C2   : 0.0
# F_a   : 1.0
# M_a   : 1.0

# %%
Shigley.AddLoadCase('Shigley_2')
Shigley.LoadCases['Shigley_2'].AddFixedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_2'].AddForce('b', Position = 0.5,Magnitude = -1)

Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# C1   : 0.0
# C2   : 0.0
# F_a   : 1.0
# M_a   : 1.0
# C1   : 0.0
# C2   : 0.0
# F_a   : 1.0
# M_a   : 0.5

# %%
Shigley.AddLoadCase('Shigley_3')
Shigley.LoadCases['Shigley_3'].AddFixedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_3'].AddDistributedLoading('b', Positions = [0,1],Magnitudes = [-1,-1])

Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# C1   : 0.0
# C2   : 0.0
# F_a   : 1.0
# M_a   : 1.0
# C1   : 0.0
# C2   : 0.0
# F_a   : 1.0
# M_a   : 0.5
# C1   : 0.0
# C2   : 0.0
# F_a   : 1.0
# M_a   : 0.5

# %%
Shigley.AddLoadCase('Shigley_4')
Shigley.LoadCases['Shigley_4'].AddFixedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_4'].AddMoment('b', Position = 1,Magnitude = 1)

Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# C1   : 0.0
# C2   : 0.0
# F_a   : 1.0
# M_a   : 1.0
# C1   : 0.0
# C2   : 0.0
# F_a   : 1.0
# M_a   : 0.5
# C1   : 0.0
# C2   : 0.0
# F_a   : 1.0
# M_a   : 0.5
# C1   : 0.0
# C2   : 0.0
# F_a   : 0.0
# M_a   : -1.0

# %%
print(Shigley.LoadCases['Shigley_4'].SolVector)
# Out:
# [ 0.  0.  0. -1.]

# %%
BeamStructure = Beam(1)

Shigley = BeamLab(BeamStructure)
Shigley.AddLoadCase('Shigley_5')
Shigley.LoadCases['Shigley_5'].AddPinnedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_5'].AddPinnedSupport('b', Position = 1)
Shigley.LoadCases['Shigley_5'].AddForce('c', Position = 0.5,Magnitude = -1)

Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# ElasticModulus: 210000000000.0
# C1   : -0.06250000000000001
# C2   : 0.0
# F_a   : 0.5
# F_b   : 0.5

# %%
print(Shigley.LoadCases['Shigley_5'].SolVector)
# Out:
# [-0.0625  0.      0.5     0.5   ]

# %%
L = 1
a = 0.4

BeamStructure = Beam(L)

Shigley = BeamLab(BeamStructure)
Shigley.AddLoadCase('Shigley_6')
Shigley.LoadCases['Shigley_6'].AddPinnedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_6'].AddPinnedSupport('b', Position = 1)
Shigley.LoadCases['Shigley_6'].AddForce('c', Position = L*a ,Magnitude = -1)

Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# ElasticModulus: 210000000000.0
# C1   : -0.064
# C2   : 0.0
# F_a   : 0.6
# F_b   : 0.4

# %%
BeamStructure = Beam(1)

Shigley = BeamLab(BeamStructure)
Shigley.AddLoadCase('Shigley_7')
Shigley.LoadCases['Shigley_7'].AddPinnedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_7'].AddPinnedSupport('b', Position = 1)
Shigley.LoadCases['Shigley_7'].AddDistributedLoading('c', Positions = [0,1],Magnitudes = [-1,-1])

Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# ElasticModulus: 210000000000.0
# C1   : -0.04166666666666667
# C2   : 0.0
# F_a   : 0.5
# F_b   : 0.5

# %%
BeamStructure = Beam(1)

Shigley = BeamLab(BeamStructure)
Shigley.AddLoadCase('Shigley_8')
Shigley.LoadCases['Shigley_8'].AddPinnedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_8'].AddPinnedSupport('b', Position = 1)
Shigley.LoadCases['Shigley_8'].AddMoment('c', Position = 0.5 ,Magnitude = 1)

Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# ElasticModulus: 210000000000.0
# C1   : -0.04166666666666668
# C2   : 0.0
# F_a   : 1.0
# F_b   : -1.0

# %%
BeamStructure = Beam(1)

Shigley = BeamLab(BeamStructure)
Shigley.AddLoadCase('Shigley_9')
Shigley.LoadCases['Shigley_9'].AddPinnedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_9'].AddPinnedSupport('b', Position = 1)
Shigley.LoadCases['Shigley_9'].AddForce('c', Position = 0.3 ,Magnitude = -1)
Shigley.LoadCases['Shigley_9'].AddForce('d', Position = 0.7 ,Magnitude = -1)

Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# ElasticModulus: 210000000000.0
# C1   : -0.10500000000000002
# C2   : 0.0
# F_a   : 1.0
# F_b   : 1.0

# %%
BeamStructure = Beam(1)

Shigley = BeamLab(BeamStructure)
Shigley.AddLoadCase('Shigley_10')
Shigley.LoadCases['Shigley_10'].AddPinnedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_10'].AddPinnedSupport('b', Position = 0.7)
Shigley.LoadCases['Shigley_10'].AddForce('c', Position = 1 ,Magnitude = -1)
Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# ElasticModulus: 210000000000.0
# C1   : 0.034999999999999996
# C2   : 0.0
# F_a   : -0.4285714285714286
# F_b   : 1.4285714285714286

# %%
BeamStructure = Beam(1)

Shigley = BeamLab(BeamStructure)
Shigley.AddLoadCase('Shigley_11')
Shigley.LoadCases['Shigley_11'].AddFixedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_11'].AddPinnedSupport('b', Position = 1)
Shigley.LoadCases['Shigley_11'].AddForce('c', Position = 0.5 ,Magnitude = -1)
Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# ElasticModulus: 210000000000.0
# C1   : 0.0
# C2   : 0.0
# F_a   : 0.6875
# M_a   : 0.18750000000000006
# F_b   : 0.31249999999999994

# %%
BeamStructure = Beam(1)

Shigley.AddLoadCase('Shigley_12')
Shigley.LoadCases['Shigley_12'].AddFixedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_12'].AddPinnedSupport('b', Position = 1)
Shigley.LoadCases['Shigley_12'].AddForce('c', Position = 0.7 ,Magnitude = -1)
Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# ElasticModulus: 210000000000.0
# C1   : 0.0
# C2   : 0.0
# F_a   : 0.6875
# M_a   : 0.18750000000000006
# F_b   : 0.31249999999999994
# C1   : 0.0
# C2   : 0.0
# F_a   : 0.4365
# M_a   : 0.13649999999999995
# F_b   : 0.5635

# %%
BeamStructure = Beam(1)

Shigley = BeamLab(BeamStructure)
Shigley.AddLoadCase('Shigley_13')
Shigley.LoadCases['Shigley_13'].AddFixedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_13'].AddPinnedSupport('b', Position = 1)
Shigley.LoadCases['Shigley_13'].AddDistributedLoading('b', Positions = [0,1],Magnitudes = [-1,-1])
Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# ElasticModulus: 210000000000.0
# C1   : 0.0
# C2   : 0.0
# F_a   : 0.625
# M_a   : 0.12500000000000006
# F_b   : 0.37499999999999994

# %%
Shigley.AddLoadCase('Shigley_14')
Shigley.LoadCases['Shigley_14'].AddFixedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_14'].AddFixedSupport('b', Position = 1)
Shigley.LoadCases['Shigley_14'].AddForce('c', Position = 0.5 ,Magnitude = -1)
Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# C1   : 0.0
# C2   : 0.0
# F_a   : 0.625
# M_a   : 0.12500000000000006
# F_b   : 0.37499999999999994
# C1   : 0.0
# C2   : 0.0
# F_a   : 0.5000000000000001
# M_a   : 0.1250000000000001
# F_b   : 0.4999999999999999
# M_b   : -0.125

# %%
Shigley.AddLoadCase('Shigley_15')
Shigley.LoadCases['Shigley_15'].AddFixedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_15'].AddFixedSupport('b', Position = 1)
Shigley.LoadCases['Shigley_15'].AddForce('c', Position = 0.3 ,Magnitude = -1)
Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# C1   : 0.0
# C2   : 0.0
# F_a   : 0.625
# M_a   : 0.12500000000000006
# F_b   : 0.37499999999999994
# C1   : 0.0
# C2   : 0.0
# F_a   : 0.5000000000000001
# M_a   : 0.1250000000000001
# F_b   : 0.4999999999999999
# M_b   : -0.125
# C1   : 0.0
# C2   : 0.0
# F_a   : 0.7840000000000004
# M_a   : 0.14700000000000019
# F_b   : 0.21599999999999964
# M_b   : -0.06299999999999982

# %%
Shigley.AddLoadCase('Shigley_16')
Shigley.LoadCases['Shigley_16'].AddFixedSupport('a', Position = 0)
Shigley.LoadCases['Shigley_16'].AddFixedSupport('b', Position = 1)
Shigley.LoadCases['Shigley_16'].AddDistributedLoading('b', Positions = [0,1],Magnitudes = [-1,-1])
Shigley.SolveAll()
Shigley.PlotAll()
# Out:
# C1   : 0.0
# C2   : 0.0
# F_a   : 0.625
# M_a   : 0.12500000000000006
# F_b   : 0.37499999999999994
# C1   : 0.0
# C2   : 0.0
# F_a   : 0.5000000000000001
# M_a   : 0.1250000000000001
# F_b   : 0.4999999999999999
# M_b   : -0.125
# C1   : 0.0
# C2   : 0.0
# F_a   : 0.7840000000000004
# M_a   : 0.14700000000000019
# F_b   : 0.21599999999999964
# M_b   : -0.06299999999999982
# C1   : 0.0
# C2   : 0.0
# F_a   : 0.5000000000000002
# M_a   : 0.08333333333333343
# F_b   : 0.4999999999999997
# M_b   : -0.08333333333333316
